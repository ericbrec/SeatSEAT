# %%
import math
import numpy as np
import mip
from collections import namedtuple
import glob
import pandas as pd

# %%
##### Open the main sheet and define the number of games in the ticket plan #####

directory = "../examples/Mariners"
globFilename = directory + "/Full Name*.xls*"
excelFiles = glob.glob(globFilename)
if len(excelFiles) < 1 or len(excelFiles) > 1:
    print(f"Can't find unique excel file: {globFilename}")
    exit()
mainSheet = pd.read_excel(excelFiles[0])
GamesInPlan = len(mainSheet.Date)

# %%
##### Establish an object for each day of the season
 
Game = namedtuple('Game', ('month', 'day', 'gameDay', 'weekday', 'opponent', 'time', 'price'))

##### Read the season schedule and store it as a list of games
 
openingDay = mainSheet.Date[0]
schedule = []
for weekday, date, time, opponent, price in zip(mainSheet.Day, mainSheet.Date, mainSheet.Time, mainSheet.Opponent, mainSheet.Price):
    month = date.month
    day = date.day
    gameDay = date - openingDay
    time = time.strftime("%I:%M%p")
    schedule.append(Game(month, day, gameDay.days, weekday, opponent, time, price))

# %%
#########################################################

# Build a dictionary out of a list of games
#
#     buildCode == 0:    Create constraints for pair and quads
#     buildCode == 2:    Create constraint for pairs only
#     buildCode == 4:    Create constraint for quads only

def BuildDict(gameList, buildCode = 0):
    pairList = []
    for game in gameList:
        if buildCode != 4:
            pairList.append((game, 1.0))
        if buildCode != 2:
            pairList.append((game + GamesInPlan, 1.0))
    return dict(pairList)

# Define a class to contain constraints

class Constraint:
    def __init__(self, type, rhs, coefDict):
        if type == '=':
            self.type = 'E'
        if type == '<':
            self.type = 'L'
        if type == '>':
            self.type = 'G'
        self.rhs = rhs
        self.coefDict = coefDict

# Define a class to contain each person's preferences

class BaseballFan:
    def __init__(self, name, pairs, quads, ranking, extra):
        self.name = name
        self.pairs = pairs
        self.quads = quads

# Assign weights to games

        if len(ranking) != 0:
            self.ranking = ranking
        else:
            self.ranking = GamesInPlan * [GamesInPlan // 2]

# Adjust weights to favor highly ranked games

        self.useRanking = []
        midpoint = (GamesInPlan - 1) // 2
        for wgt in self.ranking:
            if wgt <= midpoint + 1:
                self.useRanking.append(math.sqrt(wgt - 1.0))
            else:
                self.useRanking.append(2.0 * math.sqrt(midpoint) - math.sqrt(2.0 * midpoint - wgt + 1))
        if len(self.useRanking) == GamesInPlan:
            self.useRanking += [2.0 * cost for cost in self.useRanking]
        else:
            for ix in range(GamesInPlan):
                self.useRanking[GamesInPlan + ix] *= 2

# Each person must attend correct number of games

        pairCon = Constraint('=', self.pairs, dict([(ix, 1.0) for ix in range(GamesInPlan)]))
        quadCon = Constraint('=', self.quads, dict([(ix, 1.0) for ix in range(GamesInPlan, 2 * GamesInPlan)]))

# Save all of the constraints for this person

        self.constraints = [pairCon, quadCon] + extra

##### This constraint handles the spacing of games

def Spacing(daysApart, comparator, value, pairsOrQuads = 0):
    firstGame = 0
    lastGame = 0
    constraintList = []
    while True:
        while lastGame < GamesInPlan and schedule[firstGame].gameDay + daysApart > schedule[lastGame].gameDay:
            lastGame += 1
        constraintList.append(Constraint(comparator, value, BuildDict(range(firstGame, lastGame), pairsOrQuads)))
        if lastGame == GamesInPlan:
            break
        while schedule[firstGame].gameDay + daysApart <= schedule[lastGame].gameDay:
            firstGame += 1
    return constraintList

##### Require or forbid games in various months

def Monthly(comparator, value, pairsOrQuads = 0):
    firstGame = 0
    lastGame = 0
    constraintList = []
    while True:
        while schedule[lastGame].month < 5:
            lastGame += 1
        while lastGame < GamesInPlan and schedule[firstGame].month == schedule[lastGame].month:
            lastGame += 1
        constraintList.append(Constraint(comparator, value, BuildDict(range(firstGame, lastGame), pairsOrQuads)))
        if lastGame == GamesInPlan:
            break
        firstGame = lastGame
    return constraintList

##### Require or forbid games in different series

def Series(comparator, value, pairsOrQuads = 0):
    firstGame = 0
    lastGame = 0
    constraintList = []
    while True:
        while lastGame < GamesInPlan and schedule[firstGame].opponent == schedule[lastGame].opponent:
            lastGame += 1
        constraintList.append(Constraint(comparator, value, BuildDict(range(firstGame, lastGame), pairsOrQuads)))
        if lastGame == GamesInPlan:
            break
        firstGame = lastGame
    return constraintList

def Reweight(priority):
    nprior = list (range (GamesInPlan))
    for ix, ranking in enumerate(priority):
        smallest = 1000
        for iy, myRanking in enumerate(priority):
            if myRanking < smallest:
                ixSmallest = iy
                smallest = myRanking
        nprior[ixSmallest] = np.int64(ix + 1)
        priority[ixSmallest] = 1000
    return nprior

# %%
##### Define the participants here #####

fans = []
totalPairs = 0
for fullName, nPairs, nQuads in zip(mainSheet.FullName, mainSheet.Pairs, mainSheet.Quads):
    if not isinstance(fullName, str) or fullName == "":
        break
    totalPairs += nPairs + 2 * nQuads
    globFilename = directory + "/" + fullName + "*.xls*"
    excelFiles = glob.glob(globFilename)
    if len(excelFiles) < 1 or len(excelFiles) > 1:
        print(f"Can't find unique excel file: {globFilename}")
        continue
    fanSheet = pd.read_excel(excelFiles[0])
    pairsRank = [rank for rank in fanSheet.Pick]
    pairsRank = Reweight(pairsRank)
    quadsRank = [quadRank for quadRank in fanSheet.QuadPick]
    if not isinstance(quadsRank[0], np.float64) and not math.isnan(quadsRank[0]):
        pairsRank += Reweight(quadsRank)
    print(fullName, nPairs, nQuads, len(pairsRank))

    # Add fan constraints (starting at row 35)
    extraConstraints = []
    constraintRow = 35
    if fanSheet.iat[constraintRow,1]:
        constraintValue = fanSheet.iat[constraintRow, 3]
        extraConstraints += Monthly('>', constraintValue)
    constraintRow += 1
    if fanSheet.iat[constraintRow,1]:
        constraintValue = fanSheet.iat[constraintRow, 3]
        extraConstraints += Monthly('<', constraintValue)
    constraintRow += 1
    if fanSheet.iat[constraintRow,1]:
        constraintValue = fanSheet.iat[constraintRow, 3]
        extraConstraints += Monthly('>', constraintValue, 2)
    constraintRow += 1
    if fanSheet.iat[constraintRow,1]:
        constraintValue = fanSheet.iat[constraintRow, 3]
        extraConstraints += Monthly('<', constraintValue, 2)
    constraintRow += 1
    if fanSheet.iat[constraintRow,1]:
        constraintValue = fanSheet.iat[constraintRow, 3]
        extraConstraints += Monthly('>', constraintValue, 4)
    constraintRow += 1
    if fanSheet.iat[constraintRow,1]:
        constraintValue = fanSheet.iat[constraintRow, 3]
        extraConstraints += Monthly('<', constraintValue, 4)
    constraintRow += 1
    if fanSheet.iat[constraintRow,1]:
        constraintValue = fanSheet.iat[constraintRow, 3]
        extraConstraints += Spacing(constraintValue + 1, '<', 1)
    constraintRow += 1
    if fanSheet.iat[constraintRow,1]:
        constraintValue = fanSheet.iat[constraintRow, 3]
        extraConstraints += Spacing(constraintValue + 1, '>', 1)
    constraintRow += 1
    if fanSheet.iat[constraintRow,1]:
        constraintValue = fanSheet.iat[constraintRow, 3]
        extraConstraints += Spacing(constraintValue + 1, '<', 1)
    constraintRow += 1
    if fanSheet.iat[constraintRow,1]:
        constraintValue = fanSheet.iat[constraintRow, 3]
        extraConstraints += Spacing(constraintValue + 1, '>', 2)
    constraintRow += 1
    if fanSheet.iat[constraintRow,1]:
        constraintValue = fanSheet.iat[constraintRow, 3]
        extraConstraints += Spacing(constraintValue + 1, '<', 4)
    constraintRow += 1
    if fanSheet.iat[constraintRow,1]:
        constraintValue = fanSheet.iat[constraintRow, 3]
        extraConstraints += Spacing(constraintValue + 1, '>', 4)
    constraintRow += 1
    if fanSheet.iat[constraintRow,1]:
        constraintValue = fanSheet.iat[constraintRow, 3]
        extraConstraints += Series('<', constraintValue)
    fans.append(BaseballFan(fullName, nPairs, nQuads, pairsRank, extraConstraints))

print(totalPairs)
leftOver = 2 * GamesInPlan - totalPairs
if leftOver < 0:
    print("Too many games requested")
if leftOver > 0:
    nQuads = leftOver // 2
    nPairs = leftOver % 2
    pairsRank = (GamesInPlan * [np.int64(1)])[:]
    fans.append(BaseballFan("Spare Ticket", nPairs, nQuads, pairsRank, []))
# Out:
# Tom Grandine 10 2 81
# Al Erisman 20 2 162
# Eric Brechner 22 0 81
# 60

# %%
tixModel = mip.Model()
tixVars = [tixModel.add_var(var_type = mip.BINARY) for ix in range(2 * GamesInPlan * len(fans))]

# All tickets must be allocated

for ix in range(GamesInPlan):
    tixModel += mip.xsum(tixVars[ix + 2 * iy * GamesInPlan] + 2.0 * tixVars[ix + GamesInPlan + 2 * iy * GamesInPlan] for iy in range(len(fans))) == 2

# Each fan must attend the correct number of games + satisfy all personal constraints

for iy, fan in enumerate(fans):
    for constraint in fan.constraints:
        linfunc = mip.xsum(constraint.coefDict[ix] * tixVars[ix + iy * 2 * GamesInPlan] for ix in constraint.coefDict)
        if constraint.type == 'E':
            tixModel += linfunc == constraint.rhs
        if constraint.type == 'L':
            tixModel += linfunc <= constraint.rhs
        if constraint.type == 'G':
            tixModel += linfunc >= constraint.rhs

# Establish the objective function

costs = []
for fan in fans:
    costs += fan.useRanking
tixModel.objective = mip.xsum(costs[ix] * tixVars[ix] for ix in range(len(tixVars)))

# %%
tixModel.optimize()
# Out:
# <OptimizationStatus.INFEASIBLE: 1>

# %%
costs = (len(fans) * [0.0])[:]
print("| | | Date | Day | Opponent | Time | Cost |")
print("| :- | :- | ---: | --- | :-----: | ---: | ---- |")
for gix, game in enumerate(schedule):
    for mix, mvar in enumerate(tixModel.vars):
        if mix % GamesInPlan == gix and mvar.x > 0.5:
            fix = mix // (2 * GamesInPlan)
            if len(fans[fix].ranking) > GamesInPlan and mix % (2 * GamesInPlan) >= GamesInPlan:
                gix += GamesInPlan
            costs[fix] += 2.0 * game.price
            print("| " + fans[fix].name + " (%d)  " % (fans[fix].ranking[gix]), end = '')
            if mix % (2 * GamesInPlan) >= GamesInPlan:
                costs[fix] += 2.0 * game.price
                print("|                       ", end = '')
    for fix, fan in enumerate(fans):
        continue
    print("| %d/%d | " % (game.month, game.day) + game.weekday + " | " + game.opponent + " | " + game.time +
          " | $" + game.price + " |")
# Out:
# | | | Date | Day | Opponent | Time | Cost |
# | :- | :- | ---: | --- | :-----: | ---: | ---- |
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 6
#       4 for gix, game in enumerate(schedule):
#       5     for mix, mvar in enumerate(tixModel.vars):
# ----> 6         if mix % GamesInPlan == gix and mvar.x > 0.5:
#       7             fix = mix // (2 * GamesInPlan)
#       8             if len(fans[fix].ranking) > GamesInPlan and mix % (2 * GamesInPlan) >= GamesInPlan:
#
# Cell In[17], line 6
#       4 for gix, game in enumerate(schedule):
#       5     for mix, mvar in enumerate(tixModel.vars):
# ----> 6         if mix % GamesInPlan == gix and mvar.x > 0.5:
#       7             fix = mix // (2 * GamesInPlan)
#       8             if len(fans[fix].ranking) > GamesInPlan and mix % (2 * GamesInPlan) >= GamesInPlan:
#
# ...

# %% [markdown]
# | | | Date | Day | Opponent | Time | Cost |
# | :- | :- | ---: | --- | :-----: | ---: | ---- |
# | Eric Brechner (1)  | Tom Grandine (1)  | 3/26 | Thu | Guardians  | 07:10PM | A |
# | Mike Neff (22)  |                       | 3/27 | Fri | Guardians  | 06:45PM | B |
# | Ryan Falls (1)  |                       | 3/28 | Sat | Guardians  | 06:40PM | B |
# | Cole Graves (10)  |                       | 3/29 | Sun | Guardians  | 04:20PM | B |
# | Mike Neff (12)  |                       | 3/30 | Mon | Yankees  | 06:40PM | B |
# | Andrew Erisman (18)  |                       | 3/31 | Tue | Yankees  | 06:40PM | B |
# | Eric Brechner (50)  | Fritz Klein (7)  | 4/1 | Wed | Yankees  | 01:10PM | B |
# | Mike Neff (3)  |                       | 4/10 | Fri | Astros  | 06:40PM | B |
# | Michael Erisman  (3)  | Mike Neff (10)  | 4/11 | Sat | Astros  | 06:40PM | B |
# | Jordan Bork (21)  | Michael Rochester (17)  | 4/12 | Sun | Astros  | 01:10PM | B |
# | Cole Graves (7)  | Eric Brechner (33)  | 4/13 | Mon | Astros  | 01:10PM | C |
# | Michael Erisman  (4)  |                       | 4/17 | Fri | Rangers  | 06:40PM | B |
# | Tom Grandine (3)  |                       | 4/18 | Sat | Rangers  | 04:15PM | B |
# | Fritz Klein (7)  |                       | 4/19 | Sun | Rangers  | 01:10PM | B |
# | Michael Erisman  (6)  |                       | 4/20 | Mon | Athletics  | 06:40PM | D |
# | Eric Brechner (31)  | Michael Erisman  (7)  | 4/21 | Tue | Athletics  | 06:40PM | D |
# | Karen Boehmer (12)  |                       | 4/22 | Wed | Athletics  | 01:10PM | D |
# | Jordan Bork (3)  |                       | 5/1 | Fri | Royals  | 06:45PM | B |
# | Mike Neff (1)  | Tom Grandine (2)  | 5/2 | Sat | Royals  | 06:40PM | B |
# | Eric Brechner (8)  | Michael Rochester (15)  | 5/3 | Sun | Royals  | 01:10PM | B |
# | Al Erisman (17)  | Cole Graves (5)  | 5/4 | Mon | Braves  | 06:40PM | C |
# | Al Erisman (13)  |                       | 5/5 | Tue | Braves  | 06:40PM | C |
# | Eric Brechner (18)  | Fritz Klein (3)  | 5/6 | Wed | Braves  | 01:10PM | C |
# | Eric Brechner (17)  | Michael Erisman  (10)  | 5/15 | Fri | Padres  | 06:40PM | B |
# | Mike Neff (8)  | Tom Grandine (9)  | 5/16 | Sat | Padres  | 04:15PM | B |
# | Cole Graves (1)  |                       | 5/17 | Sun | Padres  | 04:20PM | B |
# | Al Erisman (23)  | Michael Erisman  (13)  | 5/18 | Mon | White Sox  | 06:40PM | D |
# | Andrew Erisman (25)  |                       | 5/19 | Tue | White Sox  | 06:40PM | D |
# | Karen Boehmer (4)  |                       | 5/20 | Wed | White Sox  | 01:10PM | D |
# | Al Erisman (16)  | Jordan Bork (15)  | 5/29 | Fri | D-backs  | 07:10PM | B |
# | Mike Neff (1)  |                       | 5/30 | Sat | D-backs  | 07:10PM | B |
# | Al Erisman (25)  | Eric Brechner (7)  | 5/31 | Sun | D-backs  | 01:10PM | B |
# | Cole Graves (2)  | Tom Grandine (14)  | 6/1 | Mon | Mets  | 06:40PM | B |
# | Michael Erisman  (20)  | Ryan Falls (17)  | 6/2 | Tue | Mets  | 06:40PM | B |
# | Al Erisman (29)  | Fritz Klein (9)  | 6/3 | Wed | Mets  | 12:40PM | B |
# | Tom Grandine (16)  |                       | 6/16 | Tue | Orioles  | 06:40PM | C |
# | Eric Brechner (46)  | Michael Jones (33)  | 6/17 | Wed | Orioles  | 06:40PM | C |
# | Fritz Klein (4)  | Michael Rochester (30)  | 6/18 | Thu | Orioles  | 01:10PM | C |
# | Andrew Erisman (1)  |                       | 6/19 | Fri | Red Sox  | 07:10PM | B |
# | Cole Graves (4)  |                       | 6/20 | Sat | Red Sox  | 07:10PM | B |
# | Al Erisman (5)  | Jordan Bork (1)  | 6/21 | Sun | Red Sox  | 01:10PM | A |
# | Andrew Erisman (29)  |                       | 6/29 | Mon | Angels  | 06:40PM | C |
# | Eric Brechner (28)  | Tom Grandine (36)  | 6/30 | Tue | Angels  | 06:40PM | C |
# | Andrew Erisman (31)  |                       | 7/2 | Thu | Angels  | 06:40PM | C |
# | Eric Brechner (55)  | Mike Neff (17)  | 7/3 | Fri | Blue Jays  | 07:10PM | A |
# | Jordan Bork (11)  | Michael Jones (3)  | 7/4 | Sat | Blue Jays  | 01:10PM | A |
# | Andrew Erisman (4)  |                       | 7/5 | Sun | Blue Jays  | 02:00PM | A |
# | Al Erisman (7)  | Fritz Klein (35)  | 7/17 | Fri | Giants  | 07:10PM | A |
# | Michael Jones (1)  | Mike Neff (7)  | 7/18 | Sat | Giants  | 05:08PM | A |
# | Al Erisman (9)  | Eric Brechner (6)  | 7/19 | Sun | Giants  | 01:10PM | A |
# | Ryan Falls (8)  | Tom Grandine (8)  | 7/20 | Mon | Reds  | 06:40PM | C |
# | Al Erisman (11)  | Eric Brechner (43)  | 7/21 | Tue | Reds  | 06:40PM | C |
# | Karen Boehmer (5)  |                       | 7/22 | Wed | Reds  | 12:40PM | B |
# | Karen Boehmer (7)  |                       | 7/31 | Fri | Twins  | 07:10PM | A |
# | Jordan Bork (1)  |                       | 8/1 | Sat | Twins  | 01:10PM | A |
# | Eric Brechner (67)  | Tom Grandine (60)  | 8/2 | Sun | Twins  | 01:10PM | A |
# | Ryan Falls (2)  |                       | 8/4 | Tue | Tigers  | 06:40PM | C |
# | Eric Brechner (40)  | Ryan Falls (3)  | 8/5 | Wed | Tigers  | 06:40PM | C |
# | Al Erisman (15)  | Fritz Klein (10)  | 8/6 | Thu | Tigers  | 01:10PM | B |
# | Ryan Falls (4)  |                       | 8/7 | Fri | Rays  | 07:10PM | A |
# | Eric Brechner (9)  | Tom Grandine (12)  | 8/8 | Sat | Rays  | 06:50PM | A |
# | Jordan Bork (14)  | Michael Rochester (5)  | 8/9 | Sun | Rays  | 01:10PM | A |
# | Al Erisman (1)  | Karen Boehmer (1)  | 8/21 | Fri | Cubs  | 07:10PM | A |
# | Andrew Erisman (6)  |                       | 8/22 | Sat | Cubs  | 06:40PM | A |
# | Al Erisman (3)  | Eric Brechner (5)  | 8/23 | Sun | Cubs  | 01:10PM | A |
# | Cole Graves (3)  | Tom Grandine (5)  | 8/24 | Mon | Phillies  | 06:40PM | B |
# | Eric Brechner (37)  | Ryan Falls (5)  | 8/25 | Tue | Phillies  | 06:40PM | B |
# | Al Erisman (6)  | Fritz Klein (1)  | 8/26 | Wed | Phillies  | 01:10PM | B |
# | Michael Erisman  (30)  | Michael Jones (28)  | 9/3 | Thu | Athletics  | 06:40PM | C |
# | Tom Grandine (6)  |                       | 9/4 | Fri | Athletics  | 07:10PM | B |
# | Al Erisman (8)  | Eric Brechner (2)  | 9/5 | Sat | Athletics  | 06:40PM | B |
# | Jordan Bork (21)  |                       | 9/6 | Sun | Athletics  | 01:10PM | B |
# | Andrew Erisman (14)  |                       | 9/8 | Tue | Rangers  | 06:40PM | C |
# | Eric Brechner (23)  | Tom Grandine (25)  | 9/9 | Wed | Rangers  | 06:40PM | C |
# | Fritz Klein (2)  | Ryan Falls (21)  | 9/10 | Thu | Rangers  | 01:10PM | C |
# | Fritz Klein (9)  |                       | 9/22 | Tue | Astros  | 06:40PM | C |
# | Eric Brechner (21)  | Tom Grandine (24)  | 9/23 | Wed | Astros  | 07:10PM | C |
# | Andrew Erisman (8)  |                       | 9/24 | Thu | Angels  | 06:40PM | C |
# | Cole Graves (6)  | Mike Neff (15)  | 9/25 | Fri | Angels  | 07:10PM | B |
# | Eric Brechner (4)  | Mike Neff (5)  | 9/26 | Sat | Angels  | 06:40PM | B |
# | Jordan Bork (22)  | Michael Rochester (1)  | 9/27 | Sun | Angels  | 12:10PM | B |

# %%
print("| | Amount owed | Paid |")
print("| :- | -: | -: |")
for fix, fan in enumerate(fans):
    print("| ", fan.name, " | \$%7.2f | |" % costs[fix])

# %% [markdown]
# | | Amount owed | Paid |
# | :- | -: | -: |
# |  Al Erisman  | \$2342.00 | 3/13/26 |
# |  Andrew Erisman  | \$2444.00 | 3/16/26 |
# |  Cole Graves  | \$1518.00 | 3/18/26 |
# |  Eric Brechner  | \$3148.00 | 3/13/26 |
# |  Fritz Klein  | \$1636.00 | 3/13/26 |
# |  Jordan Bork  | \$1914.00 | 3/26/26 |
# |  Karen Boehmer  | \$1196.00 | 3/15/26 |
# |  Michael Erisman   | \$1190.00 | 3/26/26 |
# |  Michael Jones  | \$ 608.00 | 4/11/26 |
# |  Michael Rochester  | \$ 730.00 | 3/15/26 |
# |  Mike Neff  | \$2214.00 | 3/31/26 |
# |  Ryan Falls  | \$1536.00 | 3/17/26 |
# |  Tom Grandine  | \$2408.00 | 3/13/26 |

# %%
picks = [[] for fan in fans]
for mix, mvar in enumerate(tixModel.vars):
    if mvar.x > 0.5:
        fix = mix // (2 * GamesInPlan)
        if len(fans[fix].ranking) > GamesInPlan:
            gix = mix % (2 * GamesInPlan)
        else:
            gix = mix % GamesInPlan
        picks[fix].append(fans[fix].ranking[gix])
for fix, fan in enumerate(fans):
    picks[fix].sort()
    picks[fix] = [int(pick) for pick in picks[fix]]
    print(fans[fix].name, picks[fix])

# %%
for gix, game in enumerate(schedule):
    picks = []
    if gix < GamesInPlan:
        for fan in fans:
            picks.append(int(fan.ranking[gix]))
    print(picks, "%2d/%2d " % (game.month, game.day) + game.weekday + " " + game.opponent + " " + game.time +
          " " + game.price)
